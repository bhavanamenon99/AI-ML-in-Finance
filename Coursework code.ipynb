# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
stocks = pd.read_excel("C:/Users/bhava/OneDrive/Desktop/SEM 2/AI&ML in Finance/1st coursework/AI_COURSEWORK DATA.xlsx",index_col= 'DATE')

# %%
stocks.head
# Out:
# <bound method NDFrame.head of                      PFGDAAU LX Equity  PFBKAAU LX Equity  PFGOAAU LX Equity  \
# DATE
# 2017-03-02 00:00:00             105.04              87.19             102.33
# 2017-10-02 00:00:00             105.04              87.19             102.33
# 2/17/2017                       105.04              87.19             102.33
# 2/24/2017                       105.04              87.19             102.33
# 2017-03-03 00:00:00             106.02              88.82             103.19
# ...                                ...                ...                ...
# 1/14/2022                       182.56             131.17             148.59
# 1/21/2022                       182.56             131.17             148.59
# 1/28/2022                       182.56             131.17             148.59
# 2022-04-02 00:00:00             182.56             131.17             148.59
# 2022-11-02 00:00:00             182.56             131.17             148.59
#
#                      AIBALMA AB Equity  CCASORI MK Equity  BCUSDLF KK Equity  \
# DATE
# 2017-03-02 00:00:00            15.7469             2.0140              10.18
# 2017-10-02 00:00:00            15.7746             2.0225              10.18
# 2/17/2017                      15.8971             2.0286              10.19
# 2/24/2017                      15.8726             2.0309              10.19
# 2017-03-03 00:00:00            15.8238             2.0302              10.19
# ...                                ...                ...                ...
# 1/14/2022                      22.6119             2.9513              10.90
# 1/21/2022                      22.5163             2.9610              10.90
# 1/28/2022                      22.5308             2.9577              10.90
# 2022-04-02 00:00:00            22.6486             2.9558              10.90
# 2022-11-02 00:00:00            22.5737             2.9707              10.90
#
#                      ALPCRDA LX Equity  PFGLAAU LX Equity  BBFTOP3 KY Equity  \
# DATE
# 2017-03-02 00:00:00             109.72              99.24            1023.80
# 2017-10-02 00:00:00             110.07              99.24            1025.36
# 2/17/2017                       110.12              99.66            1026.54
# 2/24/2017                       110.20              99.66            1028.14
# 2017-03-03 00:00:00             110.60              99.84            1029.71
# ...                                ...                ...                ...
# 1/14/2022                       138.56             135.89            1417.68
# 1/21/2022                       138.40             134.86            1421.01
# 1/28/2022                       138.23             134.86            1421.72
# 2022-04-02 00:00:00             137.75             134.86            1421.81
# 2022-11-02 00:00:00             137.62             134.86            1421.87
#
#                      CCASLTF MK Equity  LODFUIA LX Equity  PFARAAU LX Equity  \
# DATE
# 2017-03-02 00:00:00             2.5926             103.96             116.07
# 2017-10-02 00:00:00             2.6046             103.96             116.07
# 2/17/2017                       2.6160             103.96             116.07
# 2/24/2017                       2.6208             103.96             116.07
# 2017-03-03 00:00:00             2.6177             104.33             117.05
# ...                                ...                ...                ...
# 1/14/2022                       3.7834             116.57             188.58
# 1/21/2022                       3.7951             116.57             188.58
# 1/28/2022                       3.7931             116.57             188.58
# 2022-04-02 00:00:00             3.7901             116.57             188.58
# 2022-11-02 00:00:00             3.8039             116.57             188.58
#
#                      GMFDEBI LE Equity  UBSFLBI LX Equity  ALCONGP AB Equity
# DATE
# 2017-03-02 00:00:00             100.26             135.25             1.3436
# 2017-10-02 00:00:00             100.26             135.31             1.3445
# 2/17/2017                       100.26             135.48             1.3486
# 2/24/2017                       100.26             135.66             1.3499
# 2017-03-03 00:00:00             100.41             135.55             1.3497
# ...                                ...                ...                ...
# 1/14/2022                       110.04             153.63             1.7106
# 1/21/2022                       110.04             153.02             1.6913
# 1/28/2022                       110.04             152.52             1.6838
# 2022-04-02 00:00:00             109.91             152.72             1.6901
# 2022-11-02 00:00:00             109.91             152.51             1.6855
#
# [263 rows x 15 columns]>

# %%
stocks.tail
# Out:
# <bound method NDFrame.tail of                      PFGDAAU LX Equity  PFBKAAU LX Equity  PFGOAAU LX Equity  \
# DATE
# 2017-03-02 00:00:00             105.04              87.19             102.33
# 2017-10-02 00:00:00             105.04              87.19             102.33
# 2/17/2017                       105.04              87.19             102.33
# 2/24/2017                       105.04              87.19             102.33
# 2017-03-03 00:00:00             106.02              88.82             103.19
# ...                                ...                ...                ...
# 1/14/2022                       182.56             131.17             148.59
# 1/21/2022                       182.56             131.17             148.59
# 1/28/2022                       182.56             131.17             148.59
# 2022-04-02 00:00:00             182.56             131.17             148.59
# 2022-11-02 00:00:00             182.56             131.17             148.59
#
#                      AIBALMA AB Equity  CCASORI MK Equity  BCUSDLF KK Equity  \
# DATE
# 2017-03-02 00:00:00            15.7469             2.0140              10.18
# 2017-10-02 00:00:00            15.7746             2.0225              10.18
# 2/17/2017                      15.8971             2.0286              10.19
# 2/24/2017                      15.8726             2.0309              10.19
# 2017-03-03 00:00:00            15.8238             2.0302              10.19
# ...                                ...                ...                ...
# 1/14/2022                      22.6119             2.9513              10.90
# 1/21/2022                      22.5163             2.9610              10.90
# 1/28/2022                      22.5308             2.9577              10.90
# 2022-04-02 00:00:00            22.6486             2.9558              10.90
# 2022-11-02 00:00:00            22.5737             2.9707              10.90
#
#                      ALPCRDA LX Equity  PFGLAAU LX Equity  BBFTOP3 KY Equity  \
# DATE
# 2017-03-02 00:00:00             109.72              99.24            1023.80
# 2017-10-02 00:00:00             110.07              99.24            1025.36
# 2/17/2017                       110.12              99.66            1026.54
# 2/24/2017                       110.20              99.66            1028.14
# 2017-03-03 00:00:00             110.60              99.84            1029.71
# ...                                ...                ...                ...
# 1/14/2022                       138.56             135.89            1417.68
# 1/21/2022                       138.40             134.86            1421.01
# 1/28/2022                       138.23             134.86            1421.72
# 2022-04-02 00:00:00             137.75             134.86            1421.81
# 2022-11-02 00:00:00             137.62             134.86            1421.87
#
#                      CCASLTF MK Equity  LODFUIA LX Equity  PFARAAU LX Equity  \
# DATE
# 2017-03-02 00:00:00             2.5926             103.96             116.07
# 2017-10-02 00:00:00             2.6046             103.96             116.07
# 2/17/2017                       2.6160             103.96             116.07
# 2/24/2017                       2.6208             103.96             116.07
# 2017-03-03 00:00:00             2.6177             104.33             117.05
# ...                                ...                ...                ...
# 1/14/2022                       3.7834             116.57             188.58
# 1/21/2022                       3.7951             116.57             188.58
# 1/28/2022                       3.7931             116.57             188.58
# 2022-04-02 00:00:00             3.7901             116.57             188.58
# 2022-11-02 00:00:00             3.8039             116.57             188.58
#
#                      GMFDEBI LE Equity  UBSFLBI LX Equity  ALCONGP AB Equity
# DATE
# 2017-03-02 00:00:00             100.26             135.25             1.3436
# 2017-10-02 00:00:00             100.26             135.31             1.3445
# 2/17/2017                       100.26             135.48             1.3486
# 2/24/2017                       100.26             135.66             1.3499
# 2017-03-03 00:00:00             100.41             135.55             1.3497
# ...                                ...                ...                ...
# 1/14/2022                       110.04             153.63             1.7106
# 1/21/2022                       110.04             153.02             1.6913
# 1/28/2022                       110.04             152.52             1.6838
# 2022-04-02 00:00:00             109.91             152.72             1.6901
# 2022-11-02 00:00:00             109.91             152.51             1.6855
#
# [263 rows x 15 columns]>

# %%
# Plot the adjusted close price
stocks.plot(figsize=(10, 7))
# Define the label for the title of the figure
plt.title("Adjusted Close Price of stocks" % stocks, fontsize=16)
# Define the labels for x-axis and y-axis
plt.ylabel('Adj Close Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
# Show the plot
plt.show()

# %%
# Log of percentage change of all stocks in the list
stocks1 = stocks.loc[:, stocks.columns != "Date"]
print(stocks1)
# Out:
#                      PFGDAAU LX Equity  PFBKAAU LX Equity  PFGOAAU LX Equity  \
# DATE
# 2017-03-02 00:00:00             105.04              87.19             102.33
# 2017-10-02 00:00:00             105.04              87.19             102.33
# 2/17/2017                       105.04              87.19             102.33
# 2/24/2017                       105.04              87.19             102.33
# 2017-03-03 00:00:00             106.02              88.82             103.19
# ...                                ...                ...                ...
# 1/14/2022                       182.56             131.17             148.59
# 1/21/2022                       182.56             131.17             148.59
# 1/28/2022                       182.56             131.17             148.59
# 2022-04-02 00:00:00             182.56             131.17             148.59
# 2022-11-02 00:00:00             182.56             131.17             148.59
#
#                      AIBALMA AB Equity  CCASORI MK Equity  BCUSDLF KK Equity  \
# DATE
# 2017-03-02 00:00:00            15.7469             2.0140              10.18
# 2017-10-02 00:00:00            15.7746             2.0225              10.18
# 2/17/2017                      15.8971             2.0286              10.19
# 2/24/2017                      15.8726             2.0309              10.19
# 2017-03-03 00:00:00            15.8238             2.0302              10.19
# ...                                ...                ...                ...
# 1/14/2022                      22.6119             2.9513              10.90
# 1/21/2022                      22.5163             2.9610              10.90
# 1/28/2022                      22.5308             2.9577              10.90
# 2022-04-02 00:00:00            22.6486             2.9558              10.90
# 2022-11-02 00:00:00            22.5737             2.9707              10.90
#
#                      ALPCRDA LX Equity  PFGLAAU LX Equity  BBFTOP3 KY Equity  \
# DATE
# 2017-03-02 00:00:00             109.72              99.24            1023.80
# 2017-10-02 00:00:00             110.07              99.24            1025.36
# 2/17/2017                       110.12              99.66            1026.54
# 2/24/2017                       110.20              99.66            1028.14
# 2017-03-03 00:00:00             110.60              99.84            1029.71
# ...                                ...                ...                ...
# 1/14/2022                       138.56             135.89            1417.68
# 1/21/2022                       138.40             134.86            1421.01
# 1/28/2022                       138.23             134.86            1421.72
# 2022-04-02 00:00:00             137.75             134.86            1421.81
# 2022-11-02 00:00:00             137.62             134.86            1421.87
#
#                      CCASLTF MK Equity  LODFUIA LX Equity  PFARAAU LX Equity  \
# DATE
# 2017-03-02 00:00:00             2.5926             103.96             116.07
# 2017-10-02 00:00:00             2.6046             103.96             116.07
# 2/17/2017                       2.6160             103.96             116.07
# 2/24/2017                       2.6208             103.96             116.07
# 2017-03-03 00:00:00             2.6177             104.33             117.05
# ...                                ...                ...                ...
# 1/14/2022                       3.7834             116.57             188.58
# 1/21/2022                       3.7951             116.57             188.58
# 1/28/2022                       3.7931             116.57             188.58
# 2022-04-02 00:00:00             3.7901             116.57             188.58
# 2022-11-02 00:00:00             3.8039             116.57             188.58
#
#                      GMFDEBI LE Equity  UBSFLBI LX Equity  ALCONGP AB Equity
# DATE
# 2017-03-02 00:00:00             100.26             135.25             1.3436
# 2017-10-02 00:00:00             100.26             135.31             1.3445
# 2/17/2017                       100.26             135.48             1.3486
# 2/24/2017                       100.26             135.66             1.3499
# 2017-03-03 00:00:00             100.41             135.55             1.3497
# ...                                ...                ...                ...
# 1/14/2022                       110.04             153.63             1.7106
# 1/21/2022                       110.04             153.02             1.6913
# 1/28/2022                       110.04             152.52             1.6838
# 2022-04-02 00:00:00             109.91             152.72             1.6901
# 2022-11-02 00:00:00             109.91             152.51             1.6855
#
# [263 rows x 15 columns]

# %%
stocks1.columns
# Out:
# Index(['PFGDAAU LX Equity', 'PFBKAAU LX Equity', 'PFGOAAU LX Equity',
#        'AIBALMA AB Equity', 'CCASORI MK Equity', 'BCUSDLF KK Equity',
#        'ALPCRDA LX Equity', 'PFGLAAU LX Equity', 'BBFTOP3 KY Equity',
#        'CCASLTF MK Equity', 'LODFUIA LX Equity', 'PFARAAU LX Equity',
#        'GMFDEBI LE Equity', 'UBSFLBI LX Equity', 'ALCONGP AB Equity'],
#       dtype='object')

# %%
# Log of percentage change of all stocks in the list
Ret= stocks.pct_change().apply(lambda x: np.log(1+x)) # CONVERT TO RETURN
Ret.head()
# Out:
#                      PFGDAAU LX Equity  PFBKAAU LX Equity  PFGOAAU LX Equity  \
# DATE
# 2017-03-02 00:00:00                NaN                NaN                NaN
# 2017-10-02 00:00:00           0.000000           0.000000           0.000000
# 2/17/2017                     0.000000           0.000000           0.000000
# 2/24/2017                     0.000000           0.000000           0.000000
# 2017-03-03 00:00:00           0.009287           0.018522           0.008369
#
#                      AIBALMA AB Equity  CCASORI MK Equity  BCUSDLF KK Equity  \
# DATE
# 2017-03-02 00:00:00                NaN                NaN                NaN
# 2017-10-02 00:00:00           0.001758           0.004212           0.000000
# 2/17/2017                     0.007736           0.003012           0.000982
# 2/24/2017                    -0.001542           0.001133           0.000000
# 2017-03-03 00:00:00          -0.003079          -0.000345           0.000000
#
#                      ALPCRDA LX Equity  PFGLAAU LX Equity  BBFTOP3 KY Equity  \
# DATE
# 2017-03-02 00:00:00                NaN                NaN                NaN
# 2017-10-02 00:00:00           0.003185           0.000000           0.001523
# 2/17/2017                     0.000454           0.004223           0.001150
# 2/24/2017                     0.000726           0.000000           0.001557
# 2017-03-03 00:00:00           0.003623           0.001805           0.001526
#
#                      CCASLTF MK Equity  LODFUIA LX Equity  PFARAAU LX Equity  \
# DATE
# 2017-03-02 00:00:00                NaN                NaN                NaN
# 2017-10-02 00:00:00           0.004618           0.000000           0.000000
# 2/17/2017                     0.004367           0.000000           0.000000
# 2/24/2017                     0.001833           0.000000           0.000000
# 2017-03-03 00:00:00          -0.001184           0.003553           0.008408
#
#                      GMFDEBI LE Equity  UBSFLBI LX Equity  ALCONGP AB Equity
# DATE
# 2017-03-02 00:00:00                NaN                NaN                NaN
# 2017-10-02 00:00:00           0.000000           0.000444           0.000670
# 2/17/2017                     0.000000           0.001256           0.003045
# 2/24/2017                     0.000000           0.001328           0.000963
# 2017-03-03 00:00:00           0.001495          -0.000811          -0.000148

# %%
Ret.plot(title='Stocks weekly returns',figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Stocks weekly returns'}, xlabel='DATE'>

# %%
Annual_Return = stocks1.mean()*52
print (Annual_Return)
# Out:
# PFGDAAU LX Equity     6694.853688
# PFBKAAU LX Equity     5355.082586
# PFGOAAU LX Equity     6203.283650
# AIBALMA AB Equity      940.020292
# CCASORI MK Equity      128.942798
# BCUSDLF KK Equity      550.084867
# ALPCRDA LX Equity     6397.951483
# PFGLAAU LX Equity     6011.629049
# BBFTOP3 KY Equity    63594.196806
# CCASLTF MK Equity      165.729141
# LODFUIA LX Equity     5759.217490
# PFARAAU LX Equity     7542.635589
# GMFDEBI LE Equity     5508.609125
# UBSFLBI LX Equity     7506.627072
# ALCONGP AB Equity       78.958777
# dtype: float64

# %%
Annual_Risk = Ret.std()*(52)**(0.5)
print(Annual_Risk)
# Out:
# PFGDAAU LX Equity    0.064625
# PFBKAAU LX Equity    0.054729
# PFGOAAU LX Equity    0.057000
# AIBALMA AB Equity    0.061199
# CCASORI MK Equity    0.014084
# BCUSDLF KK Equity    0.003394
# ALPCRDA LX Equity    0.038061
# PFGLAAU LX Equity    0.038226
# BBFTOP3 KY Equity    0.015770
# CCASLTF MK Equity    0.014803
# LODFUIA LX Equity    0.009829
# PFARAAU LX Equity    0.052247
# GMFDEBI LE Equity    0.007105
# UBSFLBI LX Equity    0.014173
# ALCONGP AB Equity    0.040814
# dtype: float64

# %%
Return_Risk = (Annual_Return/Annual_Risk)
print(Return_Risk)
# Out:
# PFGDAAU LX Equity    1.035954e+05
# PFBKAAU LX Equity    9.784685e+04
# PFGOAAU LX Equity    1.088286e+05
# AIBALMA AB Equity    1.536001e+04
# CCASORI MK Equity    9.155552e+03
# BCUSDLF KK Equity    1.620965e+05
# ALPCRDA LX Equity    1.680988e+05
# PFGLAAU LX Equity    1.572643e+05
# BBFTOP3 KY Equity    4.032688e+06
# CCASLTF MK Equity    1.119597e+04
# LODFUIA LX Equity    5.859206e+05
# PFARAAU LX Equity    1.443659e+05
# GMFDEBI LE Equity    7.752892e+05
# UBSFLBI LX Equity    5.296463e+05
# ALCONGP AB Equity    1.934578e+03
# dtype: float64

# %%
Return_Risk.to_excel(r'C:/Users/bhava/OneDrive/Desktop/SEM 2/AI&ML in Finance/1st coursework/ReturnRisk.xlsx')

# %%
stocks1.columns
# Out:
# Index(['PFGDAAU LX Equity', 'PFBKAAU LX Equity', 'PFGOAAU LX Equity',
#        'AIBALMA AB Equity', 'CCASORI MK Equity', 'BCUSDLF KK Equity',
#        'ALPCRDA LX Equity', 'PFGLAAU LX Equity', 'BBFTOP3 KY Equity',
#        'CCASLTF MK Equity', 'LODFUIA LX Equity', 'PFARAAU LX Equity',
#        'GMFDEBI LE Equity', 'UBSFLBI LX Equity', 'ALCONGP AB Equity'],
#       dtype='object')

# %%
assets = pd.concat([Annual_Return,Annual_Risk,Return_Risk], axis=1)
assets.columns = ['Annual Returns', 'Annual Risk', 'Return Risk Ratio']
assets
# Out:
#                    Annual Returns  Annual Risk  Return Risk Ratio
# PFGDAAU LX Equity     6694.853688     0.064625       1.035954e+05
# PFBKAAU LX Equity     5355.082586     0.054729       9.784685e+04
# PFGOAAU LX Equity     6203.283650     0.057000       1.088286e+05
# AIBALMA AB Equity      940.020292     0.061199       1.536001e+04
# CCASORI MK Equity      128.942798     0.014084       9.155552e+03
# BCUSDLF KK Equity      550.084867     0.003394       1.620965e+05
# ALPCRDA LX Equity     6397.951483     0.038061       1.680988e+05
# PFGLAAU LX Equity     6011.629049     0.038226       1.572643e+05
# BBFTOP3 KY Equity    63594.196806     0.015770       4.032688e+06
# CCASLTF MK Equity      165.729141     0.014803       1.119597e+04
# LODFUIA LX Equity     5759.217490     0.009829       5.859206e+05
# PFARAAU LX Equity     7542.635589     0.052247       1.443659e+05
# GMFDEBI LE Equity     5508.609125     0.007105       7.752892e+05
# UBSFLBI LX Equity     7506.627072     0.014173       5.296463e+05
# ALCONGP AB Equity       78.958777     0.040814       1.934578e+03

# %%
assets.to_excel(r'C:/Users/bhava/OneDrive/Desktop/SEM 2/AI&ML in Finance/1st coursework/Return-Risk Ratio.xlsx')

# %%
x=Annual_Risk
y=Annual_Return
plt.scatter(x,y)
plt.show()

# %%
Ret_Corr = Ret.corr()

# %%
cov_matrix = stocks1.pct_change().apply(lambda x: np.log(1+x)).cov()
cov_matrix
# Out:
#                    PFGDAAU LX Equity  PFBKAAU LX Equity  PFGOAAU LX Equity  \
# PFGDAAU LX Equity       8.031525e-05       4.621507e-05       4.944730e-05
# PFBKAAU LX Equity       4.621507e-05       5.760170e-05       4.193674e-05
# PFGOAAU LX Equity       4.944730e-05       4.193674e-05       6.248181e-05
# AIBALMA AB Equity      -7.356645e-06      -4.229364e-06       5.562801e-08
# CCASORI MK Equity      -3.752553e-06      -1.866554e-06      -2.117118e-06
# BCUSDLF KK Equity      -2.532342e-07      -1.117518e-07      -1.230032e-07
# ALPCRDA LX Equity       2.449596e-06       3.397873e-06       4.124025e-06
# PFGLAAU LX Equity       1.633960e-05       1.725807e-05       2.001122e-05
# BBFTOP3 KY Equity      -1.271514e-06      -1.113535e-06      -7.251269e-07
# CCASLTF MK Equity      -1.862485e-06      -8.364942e-07      -8.068300e-07
# LODFUIA LX Equity       6.608284e-06       5.782150e-06       5.313650e-06
# PFARAAU LX Equity       4.810340e-05       4.941889e-05       4.179429e-05
# GMFDEBI LE Equity       3.167436e-06       3.020380e-06       3.211947e-06
# UBSFLBI LX Equity      -5.988708e-07       4.149360e-07       2.593302e-07
# ALCONGP AB Equity      -2.477016e-06       1.706629e-06       2.206257e-06
#
#                    AIBALMA AB Equity  CCASORI MK Equity  BCUSDLF KK Equity  \
# PFGDAAU LX Equity      -7.356645e-06      -3.752553e-06      -2.532342e-07
# PFBKAAU LX Equity      -4.229364e-06      -1.866554e-06      -1.117518e-07
# PFGOAAU LX Equity       5.562801e-08      -2.117118e-06      -1.230032e-07
# CCASLTF MK Equity       4.213769e-06      -4.545397e-07      -1.273496e-06
# LODFUIA LX Equity      -4.545397e-07       1.858002e-06       6.707342e-06
# PFARAAU LX Equity      -1.273496e-06       6.707342e-06       5.249448e-05
# GMFDEBI LE Equity      -2.580751e-07       9.573377e-07       3.526000e-06
# UBSFLBI LX Equity       5.143001e-07      -2.978783e-08       3.417107e-07
# ALCONGP AB Equity       1.829597e-06      -1.261876e-07       1.595704e-07
#
#                    GMFDEBI LE Equity  UBSFLBI LX Equity  ALCONGP AB Equity
# PFGDAAU LX Equity       3.167436e-06      -5.988708e-07      -2.477016e-06
# PFBKAAU LX Equity       3.020380e-06       4.149360e-07       1.706629e-06
# PFGOAAU LX Equity       3.211947e-06       2.593302e-07       2.206257e-06
# AIBALMA AB Equity      -3.870392e-07       6.939346e-06       2.761479e-05
# CCASORI MK Equity      -4.467473e-07       5.672470e-07       2.520090e-06
# BCUSDLF KK Equity       2.103251e-08       8.968564e-09       9.824752e-08
# ALPCRDA LX Equity       4.689369e-07       1.167050e-06       2.588887e-06
# PFGLAAU LX Equity       1.044518e-06       2.591217e-06       5.637178e-06
# BBFTOP3 KY Equity       1.814409e-07       2.636407e-07       7.989210e-07
# CCASLTF MK Equity      -2.580751e-07       5.143001e-07       1.829597e-06
# LODFUIA LX Equity       9.573377e-07      -2.978783e-08      -1.261876e-07
# PFARAAU LX Equity       3.526000e-06       3.417107e-07       1.595704e-07
# GMFDEBI LE Equity       9.708521e-07       5.889408e-08       6.906775e-08
# UBSFLBI LX Equity       5.889408e-08       3.862909e-06       8.171694e-06
# ALCONGP AB Equity       6.906775e-08       8.171694e-06       3.203502e-05

# %%
w = {'PFGDAAU LX Equity':0.043,'PFBKAAU LX Equity':0.043,'PFGOAAU LX Equity':0.043,'AIBALMA AB Equity':0.043,'CCASORI MK Equity':0.043,'BCUSDLF KK Equity':0.043,'ALPCRDA LX Equity':0.043,'PFGLAAU LX Equity':0.043, 'BBFTOP3 KY Equity':0.043, 'CCASLTF MK Equity':0.043,'LODFUIA LX Equity':0.043,'PFARAAU LX Equity':0.043,'GMFDEBI LE Equity':0.043,'UBSFLBI LX Equity':0.043, 'ALCONGP AB Equity':0.043, } 
port_var = Ret_Covar.mul(w, axis=0).mul(w, axis=1).sum().sum()
Annual_port_std = (port_var*52)**(0.5)
print (port_var)
print (port_var*52)
# Out:
# 2.5140587917315823e-06
# 0.00013073105717004228

# %%
Annual_port_std
# Out:
# 0.011433768283905455

# %%
w = [0.043,0.043,0.043, 0.043,0.043,0.043,0.043,0.043,0.043,0.043,0.043,0.043,0.043,0.043,0.043]
port_er = (w*Annual_Return).sum()
port_er
# Out:
# 5264.826363853994

# %%
assets = pd.concat([Annual_Return,Annual_Risk,Return_Risk], axis=1)
assets.columns = ['Ann Returns', 'Ann Risk', 'Return Risk Ratio']
assets
# Out:
#                     Ann Returns  Ann Risk  Return Risk Ratio
# PFGDAAU LX Equity   6694.853688  0.064625       1.035954e+05
# PFBKAAU LX Equity   5355.082586  0.054729       9.784685e+04
# PFGOAAU LX Equity   6203.283650  0.057000       1.088286e+05
# AIBALMA AB Equity    940.020292  0.061199       1.536001e+04
# CCASORI MK Equity    128.942798  0.014084       9.155552e+03
# BCUSDLF KK Equity    550.084867  0.003394       1.620965e+05
# ALPCRDA LX Equity   6397.951483  0.038061       1.680988e+05
# PFGLAAU LX Equity   6011.629049  0.038226       1.572643e+05
# BBFTOP3 KY Equity  63594.196806  0.015770       4.032688e+06
# CCASLTF MK Equity    165.729141  0.014803       1.119597e+04
# LODFUIA LX Equity   5759.217490  0.009829       5.859206e+05
# PFARAAU LX Equity   7542.635589  0.052247       1.443659e+05
# GMFDEBI LE Equity   5508.609125  0.007105       7.752892e+05
# UBSFLBI LX Equity   7506.627072  0.014173       5.296463e+05
# ALCONGP AB Equity     78.958777  0.040814       1.934578e+03

# %%
import matplotlib.pyplot as plt
x = Annual_Risk 
y = Annual_Return
plt.scatter(x, y)
plt.show()

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights

num_assets = len(stocks1.columns)
num_portfolios = 5000

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights,Annual_Return) 
    p_ret.append(returns)
    var = Ret_Covar.mul(weights, axis=0).mul(weights, axis=1).sum().sum() # Portfolio Variance
    sd = np.sqrt(var) #Daily standard deviation
    ann_sd = sd*np.sqrt(52) #Annual standard deviation = volatility
    p_vol.append(ann_sd)

# %%
data = {'Returns':p_ret, 'Risk':p_vol}
for counter, symbol in enumerate(stocks1.columns.tolist()):
#print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in p_weights]
portfolios = pd.DataFrame(data)
portfolios.head() # Dataframe of the 10000 portfolios created
# Out:
#         Returns      Risk  PFGDAAU LX Equity weight  PFBKAAU LX Equity weight  \
# 0  13091.435935  0.023703                  0.123142                  0.116149
# 1   4816.999843  0.015179                  0.058898                  0.075076
# 2   4866.260379  0.019286                  0.083969                  0.127361
# 3   4685.556434  0.017628                  0.089807                  0.071916
# 4  12249.847460  0.022449                  0.148933                  0.116452
#
#    PFGOAAU LX Equity weight  AIBALMA AB Equity weight  \
# 0                  0.083294                  0.029676
# 1                  0.014613                  0.061501
# 2                  0.037172                  0.012932
# 3                  0.063838                  0.075474
# 4                  0.075442                  0.003233
#
#    CCASORI MK Equity weight  BCUSDLF KK Equity weight  \
# 0                  0.010055                  0.065802
# 1                  0.119918                  0.029657
# 2                  0.084552                  0.066408
# 3                  0.098424                  0.050308
# 4                  0.063892                  0.087555
#
#    ALPCRDA LX Equity weight  PFGLAAU LX Equity weight  \
# 0                  0.101810                  0.076304
# 1                  0.067192                  0.104339
# 2                  0.075470                  0.031955
# 3                  0.085642                  0.077568
# 4                  0.062502                  0.046338
#
#    BBFTOP3 KY Equity weight  CCASLTF MK Equity weight  \
# 0                  0.129919                  0.003440
# 1                  0.004349                  0.017669
# 2                  0.002364                  0.060798
# 3                  0.012836                  0.100160
# 4                  0.129237                  0.029786
#
#    LODFUIA LX Equity weight  PFARAAU LX Equity weight  \
# 0                  0.115019                  0.074509
# 1                  0.072839                  0.021219
# 2                  0.129350                  0.077623
# 3                  0.080281                  0.021189
# 4                  0.009732                  0.055229
#
#    GMFDEBI LE Equity weight  UBSFLBI LX Equity weight  \
# 0                  0.003117                  0.059679
# 1                  0.150215                  0.145502
# 2                  0.054120                  0.115199
# 3                  0.087179                  0.031717
# 4                  0.112618                  0.013731
#
#    ALCONGP AB Equity weight
# 0                  0.008085
# 1                  0.057012
# 2                  0.040727
# 3                  0.053663
# 4                  0.045321

# %%
portfolios.plot.scatter(x='Risk', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[5,5])
# Out:
# <AxesSubplot:xlabel='Risk', ylabel='Returns'>

# %%
min_vol_port = portfolios.iloc[portfolios['Risk'].idxmin()]
# idxmin() gives us the minimum value in the column specified.
min_vol_port
# Out:
# Returns                     4914.753593
# Risk                           0.010783
# PFGDAAU LX Equity weight       0.035831
# PFBKAAU LX Equity weight       0.007927
# PFGOAAU LX Equity weight       0.059295
# AIBALMA AB Equity weight       0.033057
# CCASORI MK Equity weight       0.138817
# BCUSDLF KK Equity weight       0.143363
# ALPCRDA LX Equity weight       0.038474
# PFGLAAU LX Equity weight       0.023963
# BBFTOP3 KY Equity weight       0.022270
# CCASLTF MK Equity weight       0.143320
# LODFUIA LX Equity weight       0.002170
# PFARAAU LX Equity weight       0.058049
# GMFDEBI LE Equity weight       0.144742
# UBSFLBI LX Equity weight       0.140980
# ALCONGP AB Equity weight       0.007742
# Name: 576, dtype: float64

# %%
plt.subplots(figsize=[6,5])
# Out:
# (<Figure size 432x360 with 1 Axes>, <AxesSubplot:>)

# %%
plt.scatter(portfolios['Risk'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=200)

# %%
# Finding the optimal portfolio
rf = 0.01 # risk factor
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Risk']).idxmax()]
optimal_risky_port
# Out:
# Returns                     13597.291147
# Risk                            0.011195
# PFGDAAU LX Equity weight        0.052161
# PFBKAAU LX Equity weight        0.028545
# PFGOAAU LX Equity weight        0.020431
# AIBALMA AB Equity weight        0.064620
# CCASORI MK Equity weight        0.031427
# BCUSDLF KK Equity weight        0.002417
# ALPCRDA LX Equity weight        0.025167
# PFGLAAU LX Equity weight        0.008264
# BBFTOP3 KY Equity weight        0.154668
# CCASLTF MK Equity weight        0.101490
# LODFUIA LX Equity weight        0.152099
# PFARAAU LX Equity weight        0.025780
# GMFDEBI LE Equity weight        0.161164
# UBSFLBI LX Equity weight        0.116735
# ALCONGP AB Equity weight        0.055033
# Name: 3419, dtype: float64

# %%
plt.subplots(figsize=(5, 6))
plt.scatter(portfolios['Risk'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)

# %%
portfolios.plot.scatter(x='Risk', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[5,5])
# Out:
# <AxesSubplot:xlabel='Risk', ylabel='Returns'>
